# %% [markdown]
# <a href="https://colab.research.google.com/github/rajshaiwalla/NLP-Submissions/blob/master/spaCy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #importing for using dataframes
import spacy #importing spacy

# %%
sp = spacy.load('en')

# %%
data = pd.read_json("http://snap.stanford.edu/data/amazon/productGraph/categoryFiles/reviews_Office_Products_5.json.gz", lines = True) #Reading the Office Products file

# %%
data.head(10) #viewing the first 10 rows of the data
# Out:
#        reviewerID        asin  ... unixReviewTime   reviewTime
# 0  A32T2H8150OJLU  B00000JBLH  ...     1094169600   09 3, 2004
# 1  A3MAFS04ZABRGO  B00000JBLH  ...     1197676800  12 15, 2007
# 2  A1F1A0QQP2XVH5  B00000JBLH  ...     1293840000   01 1, 2011
# 3   A49R5DBXXQDE5  B00000JBLH  ...     1145404800  04 19, 2006
# 4  A2XRMQA6PJ5ZJ8  B00000JBLH  ...     1375574400   08 4, 2013
# 5  A2JFOHC9W629IE  B00000JBLH  ...     1011744000  01 23, 2002
# 6  A38NELQT98S4H8  B00000JBLH  ...     1168992000  01 17, 2007
# 7   AA8M6331NI1EN  B00000JBLH  ...     1384387200  11 14, 2013
# 8  A25C2M3QF9G7OQ  B00000JBLU  ...     1291680000   12 7, 2010
# 9  A1RTVWTWZSIC94  B00000JBLU  ...     1385942400   12 2, 2013
#
# [10 rows x 9 columns]

# %%
df = data.copy() #making a copy of the data and storing it in 'df' to leave the original data unaltered.

# %%
line = df['reviewText'][0] #storing the string as 'line'
line
# Out:
# "I bought my first HP12C in about 1984 or so, and it served me faithfully until 2002 when I lost it while travelling.  I searched for another one to replace it, but found one difficult to come by in my area.  So, I decided to buy up and purchased an HP 49G.  What a mistake!  I know that many people view the HP 49G (now 49G+) as the flagship of the HP line, but for me that was a disaster.The 49G may be powerful, but using it is extremely counterintuitive...and the manual was sketchy at best.  The 12C, on the other hand, does what I need in a way that makes good sense to me.If you are looking for a solid, reliable calculator, the HP12C may be for you.  It's programmable.  It does basic statistics well, and many business applications too.  The manual makes sense; you will be up and running in short order.I'm ready to set my 49G aside and move back to my old friend.  I didn't even have to replace the batteries in well over a decade of use!HP 12C, I'm coming home!"

# %%
def pipeline(F): #defining a function pipeline
  sentence = sp(F)
  token = []
  lemma = []
  pos = []
  dep = []
  noun = []
  for word in sentence:
    token.append(word.text)
    lemma.append(word.lemma_)
    pos.append(word.pos_)
    dep.append(word.dep_)
    table = list(zip(token,pos))
    for x in table:
      if x[1]=='NOUN':
        noun.append(x[0])
  dic = {'token':token, 'lemma':lemma, 'pos':pos, 'dependency':dep, 'noun':noun}
  return dic

# %%
pipeline(line) #applying pipeline to line
# Out:
# {'dependency': ['nsubj',
#   'ROOT',
#   'poss',
#   'amod',
#   'dobj',
#   'prep',
#   'advmod',
#   'pobj',
#   'cc',
#   'conj',
#   'punct',
#   'cc',
#   'nsubj',
#   'conj',
#   'dobj',
#   'advmod',
#   'prep',
#   'pobj',
#   'advmod',
#   'nsubj',
#   'relcl',
#   'dobj',
#   'mark',
#   'advcl',
#   'punct',
#   '',
#   'nsubj',
#   'ROOT',
#   'prep',
#   'det',
#   'pobj',
#   'aux',
#   'relcl',
#   'dobj',
#   'punct',
#   'cc',
#   'conj',
#   'nsubj',
#   'ccomp',
#   'aux',
#   'xcomp',
#   'prt',
#   'prep',
#   'poss',
#   'pobj',
#   'punct',
#   '',
#   'advmod',
#   'punct',
#   'nsubj',
#   'ROOT',
#   'aux',
#   'xcomp',
#   'prt',
#   'cc',
#   'conj',
#   'det',
#   'compound',
#   'dobj',
#   '',
#   'det',
#   'det',
#   'ROOT',
#   'punct',
#   '',
#   'nsubj',
#   'ROOT',
#   'mark',
#   'amod',
#   'nsubj',
#   'ccomp',
#   'det',
#   'nmod',
#   'nummod',
#   'dobj',
#   'punct',
#   'advmod',
#   'appos',
#   'punct',
#   'prep',
#   'det',
# ...

# %%
test = df['reviewText'][0:50] #making a 'test' dataframe of df consisting first 50 rows
test = pd.DataFrame(test)

# %%
test['Pipeline_ReviewText'] = test['reviewText'].apply(pipeline) #applying pipeline to the test dataframe

# %%
test.head(10) #displaying first 10 rows of test
# Out:
#                                           reviewText                                Pipeline_ReviewText
# 0  I bought my first HP12C in about 1984 or so, a...  {'token': ['I', 'bought', 'my', 'first', 'HP12...
# 1  WHY THIS BELATED REVIEW? I feel very obliged t...  {'token': ['WHY', 'THIS', 'BELATED', 'REVIEW',...
# 2  I have an HP 48GX that has been kicking for mo...  {'token': ['I', 'have', 'an', 'HP', '48GX', 't...
# 3  I've started doing more finance stuff recently...  {'token': ['I', ''ve', 'started', 'doing', 'mo...
# 4  For simple calculations and discounted cash fl...  {'token': ['For', 'simple', 'calculations', 'a...
# 5  While I don't have an MBA, it's hard to believ...  {'token': ['While', 'I', 'do', 'n't', 'have', ...
# 6  I've had an HP 12C ever since they were first ...  {'token': ['I', ''ve', 'had', 'an', 'HP', '12C...
# 7  Bought this for my boss because he lost his.  ...  {'token': ['Bought', 'this', 'for', 'my', 'bos...
# ...

# %%
test['Pipeline_ReviewText'][0] #applying pipeline to the first row of 'Pipeline_ReviewText' collumn in test dataframe (test['Pipeline_ReviewText'][0] = pipeline(line))
# Out:
# {'dependency': ['nsubj',
#   'ROOT',
#   'poss',
#   'amod',
#   'dobj',
#   'prep',
#   'advmod',
#   'pobj',
#   'cc',
#   'conj',
#   'punct',
#   'cc',
#   'nsubj',
#   'conj',
#   'dobj',
#   'advmod',
#   'prep',
#   'pobj',
#   'advmod',
#   'nsubj',
#   'relcl',
#   'dobj',
#   'mark',
#   'advcl',
#   'punct',
#   '',
#   'nsubj',
#   'ROOT',
#   'prep',
#   'det',
#   'pobj',
#   'aux',
#   'relcl',
#   'dobj',
#   'punct',
#   'cc',
#   'conj',
#   'nsubj',
#   'ccomp',
#   'aux',
#   'xcomp',
#   'prt',
#   'prep',
#   'poss',
#   'pobj',
#   'punct',
#   '',
#   'advmod',
#   'punct',
#   'nsubj',
#   'ROOT',
#   'aux',
#   'xcomp',
#   'prt',
#   'cc',
#   'conj',
#   'det',
#   'compound',
#   'dobj',
#   '',
#   'det',
#   'det',
#   'ROOT',
#   'punct',
#   '',
#   'nsubj',
#   'ROOT',
#   'mark',
#   'amod',
#   'nsubj',
#   'ccomp',
#   'det',
#   'nmod',
#   'nummod',
#   'dobj',
#   'punct',
#   'advmod',
#   'appos',
#   'punct',
#   'prep',
#   'det',
# ...
